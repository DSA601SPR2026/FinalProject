# %%
import pandas as pd
from NHANES_Utility.NHANES_Utility import get_column_metadata, code_lookup
pd.set_option('display.max_columns', None)

# %%
code_lookup("RIDAGEYR")
# Out:
# RIDAGEYR
# Age in years of the participant at the time of screening. Individuals 80 and over are top-coded at 80 years of age.
# https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2021/DataFiles/DEMO_L.htm#RIDAGEYR

# %%
demographics_path = "data/Demographics/"

demographics = pd.read_sas(demographics_path + "DEMO_L.XPT")
demographics.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  130378.0      12.0       2.0       1.0      43.0       NaN       5.0
# 1  130379.0      12.0       2.0       1.0      66.0       NaN       3.0
# 2  130380.0      12.0       2.0       2.0      44.0       NaN       2.0
# 3  130381.0      12.0       2.0       2.0       5.0       NaN       5.0
# 4  130382.0      12.0       2.0       1.0       2.0       NaN       3.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  DMQMILIZ  DMDBORN4  DMDYRUSR  DMDEDUC2  \
# 0       6.0       2.0       NaN       2.0       2.0       6.0       5.0
# 1       3.0       2.0       NaN       2.0       1.0       NaN       5.0
# 2       2.0       1.0       NaN       2.0       2.0       6.0       3.0
# 3       7.0       1.0      71.0       NaN       1.0       NaN       NaN
# 4       3.0       2.0      34.0       NaN       1.0       NaN       NaN
#
#    DMDMARTZ  RIDEXPRG  DMDHHSIZ  DMDHRGND  DMDHRAGZ  DMDHREDZ  DMDHRMAZ  \
# ...

# %%
column_metadata = get_column_metadata(demographics, "column_name_lookup.csv")

column_metadata.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 column_metadata = get_column_metadata(demographics, "column_name_lookup.csv")
# ----> 3 column_metadata.head()
#
# AttributeError: 'Styler' object has no attribute 'head'
